# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as stat

# %%
df=pd.read_csv(' BlackFridaySales.csv')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 550063                 NaN                 NaN       368
# ...

# %%
df.shape
# Out:
# (550068, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
df.describe(include='object')
# Out:
#        Product_ID  Gender     Age City_Category Stay_In_Current_City_Years
# count      550068  550068  550068        550068                     550068
# unique       3631       2       7             3                          5
# top     P00265242       M   26-35             B                          1
# freq         1880  414259  219587        231173                     193821

# %%
df.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %% [markdown]
# ### Data Cleaning

# %%
df['Product_Category_2']=df['Product_Category_2'].fillna(df['Product_Category_2'].mode()[0])

# %%
df['Product_Category_2'].isna().sum()
# Out:
# 0

# %%
df['Product_Category_3']=df['Product_Category_3'].fillna(df['Product_Category_3'].mode()[0])

# %%
df['Product_Category_3'].isna().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 8.0                16.0      8370
# 1                 6.0                14.0     15200
# ...

# %%
df['Gender']=df['Gender'].map({'F':'Female','M':'Male'})

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Age']=df['Age'].str.replace('+','')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21456\3759516022.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Age']=df['Age'].str.replace('+','')

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Age'].value_counts()
# Out:
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55        21504
# 0-17      15102
# Name: Age, dtype: int64

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].str.replace('+','')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21456\2063355665.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].str.replace('+','')

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4', '3', '1', '0'], dtype=object)

# %%
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].astype('int')

# %%
df['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Marital_Status']=df['Marital_Status'].map({0:'Single',1:'Married'})

# %%
df['Marital_Status'].value_counts()
# Out:
# Single     324731
# Married    225337
# Name: Marital_Status, dtype: int64

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
df['Occupation'].value_counts()
# Out:
# 4     72308
# 0     69638
# 7     59133
# 1     47426
# 17    40043
# 20    33562
# 12    31179
# 14    27309
# 2     26588
# 16    25371
# 6     20355
# 3     17650
# 10    12930
# 5     12177
# 15    12165
# 11    11586
# 19     8461
# 13     7728
# 18     6622
# 9      6291
# 8      1546
# Name: Occupation, dtype: int64

# %%
df.isna().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Numerical Feature Distribution:

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x='Purchase',kde=True,hue='Gender',palette='pastel')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x='Product_Category_1',kde=True,hue='Gender',palette='pastel',bins=100)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x='Product_Category_2',kde=True,hue='Gender',palette='pastel')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x='Product_Category_3',kde=True,hue='Gender',palette='pastel')
plt.show()

# %% [markdown]
# ### Categorical data

# %%
plt.figure(figsize=(10,5))
plt.pie(x=df['Gender'].value_counts(),labels=df['Gender'].unique(),autopct='%1.1f%%')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.pie(x=df['Age'].value_counts(),labels=df['Age'].unique(),autopct='%1.1f%%')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.pie(x=df['City_Category'].value_counts(),labels=df['City_Category'].unique(),autopct='%1.1f%%')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=df,x='Product_Category_1',y=df['Product_Category_1'].value_counts())
plt.show()

# %% [markdown]
# ### Boxplots:

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df,x='Gender',y='Purchase',palette='pastel')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df,x='Age',y='Purchase',palette='pastel')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df,x='City_Category',y='Purchase',palette='pastel')
plt.show()

# %% [markdown]
# ### Correlation Analysis:

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x=df['Product_Category_1'].value_counts().index, y=df['Product_Category_1'].value_counts().values)
plt.show()

# %% [markdown]
# ### 1.Purchase Behavior Analysis:
# #### Analyze the distribution of the Purchase amount. Are there specific groups (e.g., age groups, gender, or city categories) that tend to spend more?

# %% [markdown]
# ### Observation
# #### 1.For Gender it is shown that females purchase in between 5000 to 12000 and male purchase in between 5000 to 15000
# #### 2.For Age it is shown that all age group have in between 5000 to 14000
# #### 3.For City Category City A and c have same purchase power in between 5000 to 12000 and City C have slightly higher 15000

# %% [markdown]
# ### 2.Product Category Insights:
# #### Explore the distribution of purchases across different Product_Category_1, Product_Category_2, and Product_Category_3. Which product categories are the most popular?

# %% [markdown]
# ### observation
# #### 1.For category_1 5,1,8 are most purchase category
# #### 2.For category_2 8,14,2 are most purchase category
# #### 3.For category_3 16,15,14 are most purchase category

# %% [markdown]
# ### 3.Customer Demographics:
# #### Analyze the distribution of customers based on Age, Gender, and City_Category. Which demographic group is most active during the Black Friday sales?

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x='Gender',kde=True,hue='Gender',palette='pastel')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x='Age',kde=True,hue='Gender',palette='pastel')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x='City_Category',kde=True,hue='Gender',palette='pastel')
plt.show()

# %% [markdown]
# ### Observation
# #### 1.For Gender it is shown that females purchase very less as compare to male where male have purchase count almost 400000 and female have purchase count in between 100000 to 150000
# #### 2.For Age it is shown that age group of 26-35 have order more compare to others ther purchase count is almost 200000
# #### 3.For City Category City b have slightly higher purchase rate

# %% [markdown]
# ### 4.Impact of Occupation:
# #### Investigate the relationship between Occupation and Purchase. Are certain occupations associated with higher purchase amounts?

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=df,x=df['Occupation'].value_counts().index,y=df['Occupation'].value_counts().values)
plt.show()

# %% [markdown]
# ### Observation
# #### 1.For Occupation category 4 have more purchase power

# %% [markdown]
# ### 5.City-wise Purchase Behavior:
# #### Explore the purchase behavior across different City_Category. Are there significant differences in spending patterns among the cities?

# %% [markdown]
# ### Observation
# #### 1.For City Category City A and c have same purchase power in between 5000 to 12000 and City C have slightly higher 15000

# %% [markdown]
# ### 6.Stay in Current City:
# ### Analyze how the duration of stay in the current city (Stay_In_Current_City_Years) affects purchase behavior. Do longer stays correlate with higher spending?

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=df,x=df['Stay_In_Current_City_Years'].value_counts().index,y=df['Stay_In_Current_City_Years'].value_counts().values)
plt.show()

# %% [markdown]
# ### Observation
# #### 1.It shows that maximum purchase are made by people who in that city for 1 year

# %% [markdown]
# ###  7.Correlation Between Product Categories:
# #### Examine if there's any correlation between the three product categories (Product_Category_1, Product_Category_2, and Product_Category_3). Do customers who buy from one category tend to buy from another?

# %% [markdown]
# ### 8.Outlier Analysis:
# #### Identify any outliers in the Purchase data. How do these outliers affect the overall analysis?

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df,x='Purchase',palette='pastel')
plt.show()

# %% [markdown]
# ### Observation
# #### 1.It shows that it has few outliers

# %% [markdown]
# ###  9.Gender-wise Product Preferences:
# #### Investigate if there are significant differences in product category preferences between male and female customers.

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=df,x='Product_Category_1',y='Purchase',hue='Gender')
plt.show()

# %% [markdown]
# ### Observation
# #### 1.It is observer that category 10 has most prefered by both male and female

# %% [markdown]
# ###  10.Advanced Insights:
# #### Use advanced visualizations like heatmaps or pair plots to discover any hidden patterns or relationships within the data.

# %%
sns.heatmap(df.corr(), annot = True)
plt.title("HeatMap of Correlation Matrix")
plt.show()

# %% [markdown]
# ### Data Analysis -
#
# #### Most Populated Age Group is 26-25 years
# #### More Males than Females
# #### Occupation number 0 and 4 employ the most customers.
# #### Occupation number 8 and 9 employ the least customers.
# #### Most Customers are from City B
# #### Most customers are living in the city for 1 years
